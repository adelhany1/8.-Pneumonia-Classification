# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torch
from torch import nn, optim
import torch.nn.functional as F
from torchvision import datasets as d, models, transforms as t
from torch.utils.data import DataLoader
import csv

# %%
torch.manual_seed(1234)

# %%
batch_size = 64

mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])

transforms = {
    'train': t.Compose([#t.RandomEqualize(p=1),
                        t.RandomHorizontalFlip(),
                        t.RandomResizedCrop(224),
                        t.RandomRotation(10),
                        t.ToTensor(),
                        t.Normalize(mean, std)]),
    'val_test': t.Compose([#t.RandomEqualize(p=1),
                           t.Resize(255),
                           t.CenterCrop(224),
                           t.ToTensor(),
                           t.Normalize(mean, std)])
}

datasets = {
    'train': d.ImageFolder('model_images/train', transform=transforms['train']),
    'valid': d.ImageFolder('model_images/valid', transform=transforms['val_test']),
    'test': d.ImageFolder('model_images/test', transform=transforms['val_test'])
}

loaders = {
    'train': DataLoader(datasets['train'], batch_size=batch_size, shuffle=True),
    'valid': DataLoader(datasets['valid'], batch_size=batch_size),
    'test': DataLoader(datasets['test'], batch_size=batch_size)
}

# %%
def imshow(image, ax=None):
    image = image.numpy().transpose((1, 2, 0))
    image = image * std + mean
    image = np.clip(image, 0, 1)
    ax.imshow(image) if ax else plt.imshow(image)

# %%
img, _ = next(iter(loaders['train']))
imshow(img[0])
img[0].shape,_.shape
# Out:
# (torch.Size([3, 224, 224]), torch.Size([64]))

# %%
classes = datasets['train'].classes
images, labels = next(iter(loaders['train']))

fig, axes = plt.subplots(3, 5, figsize=(20, 10))
axes = axes.flatten()

for i, ax in enumerate(axes):
    imshow(images[i], ax)
    ax.set_title('Pneumonia' if int(classes[labels[i]]) else 'No Pneumonia')

plt.tight_layout()

# %% [markdown]
# ### Initialize use_cuda variable

# %%
use_cuda = torch.cuda.is_available()
use_cuda
# Out:
# True

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf
    losses=np.zeros((n_epochs,2))

    for epoch in range(n_epochs):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0

        ###################
        # train the model #
        ###################
        # set the module to training mode
        model.train()
        for data, target in loaders['train']:
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda().unsqueeze(1).float()

            optimizer.zero_grad()
            out = model(data)
            loss = criterion(out, target)
            train_loss += loss.item()
            loss.backward()
            optimizer.step()

        ######################
        # validate the model #
        ######################
        # set the model to evaluation mode
        model.eval()
        for data, target in loaders['valid']:
            with torch.no_grad():
                # move to GPU
                if use_cuda:
                    data, target = data.cuda(), target.cuda().unsqueeze(1).float()

                val_out = model(data)
                loss = criterion(val_out, target)
                valid_loss += loss.item()

        train_loss /= len(loaders['train'])
        valid_loss /= len(loaders['valid'])
        losses[epoch]=(train_loss,valid_loss)

        # print training/validation statistics
        print(
            f'Epoch: {epoch+1} \tTraining Loss: {train_loss:.6f} \tValidation Loss: {valid_loss:.6f}')

        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ... Model saved ...')
            valid_loss_min = valid_loss
            torch.save(model.state_dict(), save_path)

    return model, losses

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    y_true = np.array([])
    y_pred = np.array([])

    # set the module to evaluation mode
    model.eval()

    for data, target in loaders['test']:
        # move to GPU
        with torch.no_grad():
            if use_cuda:
                data, target = data.cuda(), target.cuda().unsqueeze(1).float()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the loss
            loss = criterion(output, target)
            # update average test loss
            test_loss += loss.item()

            output = torch.sigmoid(output)
            y_true = np.append(y_true, target.cpu().numpy())
            y_pred = np.append(y_pred, output.cpu().numpy())

            
    test_loss /= len(loaders['test'])

    print(f'Test Loss: {test_loss:.6f}\n')

    return test_loss, y_true, y_pred

# %%
model = models.googlenet(pretrained=True)

model.fc = nn.Sequential(nn.Linear(model.fc.in_features, 128, bias=False),
                         nn.BatchNorm1d(128),
                         nn.ReLU(),
                         nn.Dropout(0.25),
                         nn.Linear(128, 1))

lr = 0.0001
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
# def weights_init_normal(m):
#     classname = m.__class__.__name__
#     # for every Linear layer in a model..
#     if classname.find('Linear') != -1:
#         # get the number of the inputs
#         n = m.in_features
#         y = (1.0 / np.sqrt(n))
#         m.weight.data.normal_(0, y)
#         # m.bias.data.fill_(0)

# model.apply(weights_init_normal)

# %%
if use_cuda:
    model = model.cuda()

epochs = 50
model, losses = train(epochs, loaders, model, optimizer, criterion, use_cuda, 'model3.pt')

model.load_state_dict(torch.load('model3.pt'))
# Out:
# Epoch: 1 	Training Loss: 0.298893 	Validation Loss: 0.244293
# Validation loss decreased ... Model saved ...
# Epoch: 2 	Training Loss: 0.223956 	Validation Loss: 0.257532
# Epoch: 3 	Training Loss: 0.210344 	Validation Loss: 0.235239
# Validation loss decreased ... Model saved ...
# Epoch: 4 	Training Loss: 0.192603 	Validation Loss: 0.223900
# Validation loss decreased ... Model saved ...
# Epoch: 5 	Training Loss: 0.188964 	Validation Loss: 0.193497
# Validation loss decreased ... Model saved ...
# Epoch: 6 	Training Loss: 0.189411 	Validation Loss: 0.279607
# Epoch: 7 	Training Loss: 0.179016 	Validation Loss: 0.362230
# Epoch: 8 	Training Loss: 0.176545 	Validation Loss: 0.241778
# Epoch: 9 	Training Loss: 0.174745 	Validation Loss: 0.373270
# Epoch: 10 	Training Loss: 0.173385 	Validation Loss: 0.357838
# Epoch: 11 	Training Loss: 0.168193 	Validation Loss: 0.267062
# Epoch: 12 	Training Loss: 0.165445 	Validation Loss: 0.283132
# Epoch: 13 	Training Loss: 0.164312 	Validation Loss: 0.302987
# Epoch: 14 	Training Loss: 0.157794 	Validation Loss: 0.230562
# Epoch: 15 	Training Loss: 0.158858 	Validation Loss: 0.336199
# Epoch: 16 	Training Loss: 0.155716 	Validation Loss: 0.294276
# Epoch: 17 	Training Loss: 0.149380 	Validation Loss: 0.225916
# Epoch: 18 	Training Loss: 0.147902 	Validation Loss: 0.220162
# Epoch: 19 	Training Loss: 0.146047 	Validation Loss: 0.322083
# Epoch: 20 	Training Loss: 0.141904 	Validation Loss: 0.279457
# Epoch: 21 	Training Loss: 0.136452 	Validation Loss: 0.460042
# Epoch: 22 	Training Loss: 0.138885 	Validation Loss: 0.264466
# Epoch: 23 	Training Loss: 0.135239 	Validation Loss: 0.309976
# Epoch: 24 	Training Loss: 0.127250 	Validation Loss: 0.362330
# Epoch: 25 	Training Loss: 0.132143 	Validation Loss: 0.295800
# Epoch: 26 	Training Loss: 0.131214 	Validation Loss: 0.275833
# Epoch: 27 	Training Loss: 0.131871 	Validation Loss: 0.258819
# Epoch: 28 	Training Loss: 0.123713 	Validation Loss: 0.309018
# Epoch: 29 	Training Loss: 0.122078 	Validation Loss: 0.291122
# Epoch: 30 	Training Loss: 0.115087 	Validation Loss: 0.360321
# Epoch: 31 	Training Loss: 0.116705 	Validation Loss: 0.436834
# Epoch: 32 	Training Loss: 0.115046 	Validation Loss: 0.316845
# Epoch: 33 	Training Loss: 0.110944 	Validation Loss: 0.261799
# Epoch: 34 	Training Loss: 0.106811 	Validation Loss: 0.345784
# Epoch: 35 	Training Loss: 0.103706 	Validation Loss: 0.288347
# Epoch: 36 	Training Loss: 0.104289 	Validation Loss: 0.344223
# Epoch: 37 	Training Loss: 0.103456 	Validation Loss: 0.338736
# Epoch: 38 	Training Loss: 0.102056 	Validation Loss: 0.349634
# Epoch: 39 	Training Loss: 0.105024 	Validation Loss: 0.451059
# Epoch: 40 	Training Loss: 0.101139 	Validation Loss: 0.396159
# Epoch: 41 	Training Loss: 0.094462 	Validation Loss: 0.545985
# Epoch: 42 	Training Loss: 0.104031 	Validation Loss: 0.344600
# Epoch: 43 	Training Loss: 0.087763 	Validation Loss: 0.493557
# Epoch: 44 	Training Loss: 0.093128 	Validation Loss: 0.281029
# Epoch: 45 	Training Loss: 0.088063 	Validation Loss: 0.500555
# Epoch: 46 	Training Loss: 0.088552 	Validation Loss: 0.433104
# Epoch: 47 	Training Loss: 0.092453 	Validation Loss: 0.500758
# Epoch: 48 	Training Loss: 0.091708 	Validation Loss: 0.368696
# Epoch: 49 	Training Loss: 0.091748 	Validation Loss: 0.498995
# Epoch: 50 	Training Loss: 0.083433 	Validation Loss: 0.420791
# <All keys matched successfully>

# %%
def plot_losses(losses):
    _,ax=plt.subplots(figsize=(10,6))
    ax.set(xlabel='Epochs',ylabel='Loss')
    ax.plot(range(1,epochs+1),losses[:,0],label='train_loss')
    ax.plot(range(1,epochs+1),losses[:,1],label='val_loss')
    ax.plot(np.argmin(losses[:, 1])+1, np.min(losses[:, 1]), marker='o', color='k', markersize=6) 
    ax.set_xticks(range(1, epochs+1, 2))
    ax.set_yticks(np.arange(0, np.max(losses[:, 1])+0.2, 0.1))
    ax.legend()

import seaborn as sns
sns.set_theme(font_scale=1.3)
plot_losses(losses)

# %%
model.load_state_dict(torch.load('model3.pt'))
test_loss, y_true, y_pred = test(loaders, model, criterion, use_cuda)
# Out:
# Test Loss: 0.182726

# %%
# Graphs functions

from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score, plot_precision_recall_curve, f1_score, confusion_matrix


def plot_auc(t_y, p_y):
    
    ## Hint: can use scikit-learn's built in functions here like roc_curve
    
    # Todo
    
    fig, ax = plt.subplots(1,1, figsize=(8,8))
    fpr, tpr, threshold = roc_curve(t_y, p_y)
    ax.plot(tpr, 1-fpr, label='%s (AUC:%.2f)' % ('Pneumonia', auc(fpr, tpr)))
    ax.legend()
    ax.set_xlabel('Sensitivity')
    ax.set_ylabel('Spicifity')


def pr_curve(ground_truth, probability):
    
    fig, ax = plt.subplots(1,1, figsize=(8,8))
    precision, recall, threshold = precision_recall_curve(ground_truth, probability)
    ax.plot(recall, precision, label='%s (AP Score:%.2f)' % ('Pneumonia', average_precision_score(ground_truth, probability)))
    ax.legend()
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')


def cal_F1Score(precision, recall):
    f1_score = 2*(precision * recall)/(precision + recall)
    return f1_score


def plot_f1_score(valY, pred_Y):
    
    precision, recall, threshold = precision_recall_curve(valY, pred_Y)
    f1_scores = [cal_F1Score(precision[i], recall[i]) for i in range(len(threshold))]
    max_f1_score_idx = np.argmax(f1_scores)
    
    print('Max F1 Score and corresponding Precision, recall and Threshold\n')
    print('Precision: '+ str(precision[max_f1_score_idx]))
    print('Recall: '+ str(recall[max_f1_score_idx]))
    print('Threshold: '+ str(threshold[max_f1_score_idx]))
    print('F1 Score: ' + str(f1_scores[max_f1_score_idx]))
    
    plt.figure()
    plt.plot(threshold, f1_scores)
    plt.title("F1-Score vs Threshold")
    plt.xlabel("Epoch Number")
    plt.ylabel("F1-Score")
    plt.show()
    return threshold[max_f1_score_idx]

# %%
YOUR_THRESHOLD = plot_f1_score(y_true, y_pred)
plot_auc(y_true, y_pred)
pr_curve(y_true, y_pred)
# Out:
# Max F1 Score and corresponding Precision, recall and Threshold
#
# Precision: 0.9247524752475248
# Recall: 0.7731788079470199
# Threshold: 0.7448206543922424
# F1 Score: 0.842200180342651

# %%
def store_model_info(file_path, model_name, classifier, optimizer_name, lr, min_valid_loss, test_loss):
    with open(file_path, 'a') as f:

        classifier_info = '\n'.join(str(layer) for layer in classifier)

        row = [model_name, classifier_info, optimizer_name, lr, min_valid_loss, test_loss]
        # create the csv writer
        writer = csv.writer(f)

        # write a row to the csv file
        writer.writerow(row)

# %%
min_valid_loss = min(losses[:, 1])

store_model_info('try.csv', 'resnet101', model.fc, optimizer.__class__.__name__, lr, min_valid_loss, test_loss)

# %%
def test_demo(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    tp = 0.
    tn = 0.
    fp = 0.
    fn = 0.
    y_true = np.array([])
    y_pred = np.array([])

    # set the module to evaluation mode
    model.eval()

    for data, target in loaders['test']:
        # move to GPU
        with torch.no_grad():
            if use_cuda:
                data, target = data.cuda(), target.cuda().unsqueeze(1).float()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the loss
            loss = criterion(output, target)
            # update average test loss
            test_loss += loss.item()

            output = torch.sigmoid(output)
            y_true = np.append(y_true, target.cpu().numpy())
            y_pred = np.append(y_pred, output.cpu().numpy())

            # convert output probabilities to predicted class
            pred = (torch.sigmoid(output) > 0.55).to(torch.float32)

            tp += (target * pred).sum().to(torch.float32)
            tn += ((1 - target) * (1 - pred)).sum().to(torch.float32)
            fp += ((1 - target) * pred).sum().to(torch.float32)
            fn += (target * (1 - pred)).sum().to(torch.float32)

    test_loss /= len(loaders['test'])
    sensitivity = tp / (tp + fn)
    specifity = tn / (tn + fp)
    precision = tp / (tp + fp)
    f1_score = 2 * (sensitivity * precision) / (sensitivity + precision)

    print(f'Test Loss: {test_loss:.6f}\n')

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * (tp + tn) / (tp + tn + fp + fn), (tp + tn), (tp + tn + fp + fn)))
    print(f'sensitivity = {sensitivity}')
    print(f'recall = {sensitivity}')
    print(f'specifity = {specifity}')
    print(f'precision = {precision}')
    print(f"f1 score = {f1_score}")
    print(tp, fn, tn, fp)

    return test_loss, y_true, y_pred


test_loss, y_true, y_pred = test_demo(loaders, model, criterion, use_cuda)
# Out:
# Test Loss: 0.182726
#
#
# Test Accuracy: 89% (2974/3330)
# sensitivity = 0.8725165724754333
# recall = 0.8725165724754333
# specifity = 0.8976522088050842
# precision = 0.6538461446762085
# f1 score = 0.7475177645683289
# tensor(527., device='cuda:0') tensor(77., device='cuda:0') tensor(2447., device='cuda:0') tensor(279., device='cuda:0')

# %%
test_dataset = {
    'test': d.ImageFolder('model_images copy/test', transform=transforms['val_test'])
}

test_loaders = {
    'test': DataLoader(test_dataset['test'], batch_size=batch_size)
}

# %%
test_loss, y_true, y_pred = test(test_loaders, model, criterion, use_cuda)
# Out:
# Test Loss: 0.167518

# %%
YOUR_THRESHOLD = plot_f1_score(y_true, y_pred)
plot_auc(y_true, y_pred)
pr_curve(y_true, y_pred)
# Out:
# Max F1 Score and corresponding Precision, recall and Threshold
#
# Precision: 0.5287356321839081
# Recall: 0.42790697674418604
# Threshold: 0.5865854024887085
# F1 Score: 0.47300771208226217

# %%
test_loss, y_true, y_pred = test_demo(test_loaders, model, criterion, use_cuda)
# Out:
# Test Loss: 0.167518
#
#
# Test Accuracy: 90% (4222/4685)
# sensitivity = 0.6372092962265015
# recall = 0.6372092962265015
# specifity = 0.9138702750205994
# precision = 0.262452095746994
# f1 score = 0.3717774450778961
# tensor(137., device='cuda:0') tensor(78., device='cuda:0') tensor(4085., device='cuda:0') tensor(385., device='cuda:0')

# %%
import os

# %%
model.cpu()
model.eval()
with torch.no_grad():
    for img_path in os.listdir('model_images\\valid\\1'):
        image_test = transforms['val_test'](Image.open(
            f'model_images\\valid\\1\\{img_path}').convert('RGB'))
        print(torch.sigmoid(model(image_test.unsqueeze(0))) > 0.2)
# Out:
# tensor([[True]])
# tensor([[False]])
# tensor([[True]])
# tensor([[True]])
# tensor([[True]])
# tensor([[True]])
# tensor([[False]])
# tensor([[True]])
# tensor([[True]])
# tensor([[False]])
# tensor([[True]])
# tensor([[True]])
# tensor([[True]])
# tensor([[False]])
# tensor([[False]])
# tensor([[False]])
# tensor([[True]])
# tensor([[False]])
# tensor([[True]])
# tensor([[True]])
# tensor([[False]])
# tensor([[True]])
# tensor([[False]])
# tensor([[False]])
# tensor([[True]])
# tensor([[True]])
# tensor([[True]])
# tensor([[True]])
# tensor([[False]])
# tensor([[False]])
# tensor([[True]])
# tensor([[True]])

# %%
torch.sigmoid(model(image_test.unsqueeze(0)))
# Out:
# tensor([[0.6525]], grad_fn=<SigmoidBackward>)

# %%
def predict(img_path):
    with torch.no_grad():
        img = transforms['val_test'](Image.open(
            img_path).convert('RGB')).unsqueeze(0)

        model.load_state_dict(torch.load('model.pt'))
        model.eval()
        preds = torch.sigmoid(model.forward(img))
        return preds


# test on a sample image
predict('model_images\\test\\0\\00009866_000.png')
# Out:
# tensor([[0.0066]])

# %%
def predict_show(img_path):
    preds = predict(img_path)
    img = transforms['val_test'](Image.open(img_path).convert('RGB'))
    img = img.numpy().transpose(1, 2, 0)*std+mean
    plt.imshow(img.clip(0, 1))
    print(f"{'Pneumonia' if preds > 0.2 else 'Normal'} ... Pneumonia Possibility = {preds.item()*100:.2f}%")


# test on a sample image
predict_show('model_images\\test\\1\\00016825_000.png')  # Positive
# Out:
# Pneumonia ... Pneumonia Possibility = 69.98%
